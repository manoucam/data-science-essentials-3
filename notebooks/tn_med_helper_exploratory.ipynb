# %%
import pandas as pd

# %%
ha_costs_df = pd.read_csv('../data/mmd_heart_attack_data.csv')

# %%
ha_costs_df.head(10)
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
# 5  2017    County  Average total cost  Unsmoothed actual  Base measure
# 6  2017    County  Average total cost  Unsmoothed actual  Base measure
# 7  2017    County  Average total cost  Unsmoothed actual  Base measure
# 8  2017    County  Average total cost  Unsmoothed actual  Base measure
# 9  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                    condition primary_sex  \
# 0  Primary chronic conditions  Acute myocardial infarction         All
# ...

# %%
ha_costs_df.tail(2)
# Out:
#       year geography             measure         adjustment      analysis  \
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2655  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 2654  Primary chronic conditions  Acute myocardial infarction         All
# 2655  Primary chronic conditions  Acute myocardial infarction         All
#
#      primary_age     primary_dual   fips                   county  \
# 2654         All  Dual & non-dual  72127       San Juan Municipio
# 2655         All  Dual & non-dual  72139  Trujillo Alto Municipio
#
#             state  urban primary_race primary_denominator  analysis_value
# 2654  PUERTO RICO  Urban          All           undefined           36599
# 2655  PUERTO RICO  Urban          All           undefined           26676

# %%
ha_costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 2656 non-null   int64
#  1   geography            2656 non-null   object
#  2   measure              2656 non-null   object
#  3   adjustment           2656 non-null   object
#  4   analysis             2656 non-null   object
#  5   domain               2656 non-null   object
#  6   condition            2656 non-null   object
#  7   primary_sex          2656 non-null   object
#  8   primary_age          2656 non-null   object
#  9   primary_dual         2656 non-null   object
#  10  fips                 2656 non-null   int64
#  11  county               2656 non-null   object
#  12  state                2656 non-null   object
#  13  urban                2656 non-null   object
#  14  primary_race         2656 non-null   object
# ...

# %%
TN_ha_costs_df = ha_costs_df.loc[ha_costs_df['state'] == 'TENNESSEE']

# %%
TN_ha_costs_df.shape
# Out:
# (91, 17)

# %%
TN_ha_costs_df['county'].unique()
# Out:
# array(['Anderson County', 'Bedford County', 'Benton County',
#        'Bledsoe County', 'Blount County', 'Bradley County',
#        'Campbell County', 'Cannon County', 'Carroll County',
#        'Carter County', 'Cheatham County', 'Chester County',
#        'Claiborne County', 'Clay County', 'Cocke County', 'Coffee County',
#        'Crockett County', 'Cumberland County', 'Davidson County',
#        'Decatur County', 'DeKalb County', 'Dickson County', 'Dyer County',
#        'Fayette County', 'Fentress County', 'Franklin County',
#        'Gibson County', 'Giles County', 'Grainger County',
#        'Greene County', 'Grundy County', 'Hamblen County',
#        'Hamilton County', 'Hardeman County', 'Hardin County',
#        'Hawkins County', 'Haywood County', 'Henderson County',
#        'Henry County', 'Hickman County', 'Houston County',
#        'Humphreys County', 'Jackson County', 'Jefferson County',
#        'Johnson County', 'Knox County', 'Lake County',
# ...

# %%
TN_ha_costs_df['county'].nunique()
# Out:
# 91

# %%
TN_ha_costs_df['county'].value_counts()
# Out:
# Davidson County    1
# Bedford County     1
# Chester County     1
# Hamblen County     1
# Clay County        1
#                   ..
# Haywood County     1
# McNairy County     1
# Fayette County     1
# Warren County      1
# Unicoi County      1
# Name: county, Length: 91, dtype: int64

# %%
TN_ha_costs_df['urban'].value_counts()
# Out:
# Rural    53
# Urban    38
# Name: urban, dtype: int64

# %%
cancer_cost_df = pd.read_csv('../data/mmd_cancer_data.csv')

# %%
cancer_cost_df.head
# Out:
# <bound method NDFrame.head of       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 3160  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3161  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3162  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3164  2017    County  Average total cost  Unsmoothed actual  Base measure
#
# ...

# %%
cancer_cost_df.tail
# Out:
# <bound method NDFrame.tail of       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 3160  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3161  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3162  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3164  2017    County  Average total cost  Unsmoothed actual  Base measure
#
# ...

# %%
TN_cancer_cost_df = cancer_cost_df.loc[cancer_cost_df['state'] == 'TENNESSEE']
cancer_cost_df.loc[cancer_cost_df['state'] == 'TENNESSEE']
# Out:
#       year geography             measure         adjustment      analysis  \
# 2396  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2397  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2398  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2399  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2400  2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2486  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2487  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2488  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2489  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2490  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# ...

# %%
TN_cancer_cost_df.shape
# Out:
# (95, 17)

# %%
TN_cancer_cost_df['county'].unique()
# Out:
# array(['Anderson County', 'Bedford County', 'Benton County',
#        'Bledsoe County', 'Blount County', 'Bradley County',
#        'Campbell County', 'Cannon County', 'Carroll County',
#        'Carter County', 'Cheatham County', 'Chester County',
#        'Claiborne County', 'Clay County', 'Cocke County', 'Coffee County',
#        'Crockett County', 'Cumberland County', 'Davidson County',
#        'Decatur County', 'DeKalb County', 'Dickson County', 'Dyer County',
#        'Fayette County', 'Fentress County', 'Franklin County',
#        'Gibson County', 'Giles County', 'Grainger County',
#        'Greene County', 'Grundy County', 'Hamblen County',
#        'Hamilton County', 'Hancock County', 'Hardeman County',
#        'Hardin County', 'Hawkins County', 'Haywood County',
#        'Henderson County', 'Henry County', 'Hickman County',
#        'Houston County', 'Humphreys County', 'Jackson County',
#        'Jefferson County', 'Johnson County', 'Knox County', 'Lake County',
# ...

# %%
TN_cancer_cost_df['county'].value_counts()
# Out:
# Davidson County      1
# Loudon County        1
# Hamblen County       1
# Clay County          1
# Marshall County      1
#                     ..
# Fayette County       1
# Warren County        1
# Cheatham County      1
# Williamson County    1
# Unicoi County        1
# Name: county, Length: 95, dtype: int64

# %%
TN_cancer_cost_df['county'].unique()
# Out:
# array(['Anderson County', 'Bedford County', 'Benton County',
#        'Bledsoe County', 'Blount County', 'Bradley County',
#        'Campbell County', 'Cannon County', 'Carroll County',
#        'Carter County', 'Cheatham County', 'Chester County',
#        'Claiborne County', 'Clay County', 'Cocke County', 'Coffee County',
#        'Crockett County', 'Cumberland County', 'Davidson County',
#        'Decatur County', 'DeKalb County', 'Dickson County', 'Dyer County',
#        'Fayette County', 'Fentress County', 'Franklin County',
#        'Gibson County', 'Giles County', 'Grainger County',
#        'Greene County', 'Grundy County', 'Hamblen County',
#        'Hamilton County', 'Hancock County', 'Hardeman County',
#        'Hardin County', 'Hawkins County', 'Haywood County',
#        'Henderson County', 'Henry County', 'Hickman County',
#        'Houston County', 'Humphreys County', 'Jackson County',
#        'Jefferson County', 'Johnson County', 'Knox County', 'Lake County',
# ...

# %%
TN_cancer_cost_df['county'].nunique()
# Out:
# 95

# %%
TN_cancer_cost_df.loc[~TN_cancer_cost_df['county'].isin(TN_ha_costs_df['county'])]['county']
# Out:
# 2429      Hancock County
# 2459        Moore County
# 2464      Pickett County
# 2483    Van Buren County
# Name: county, dtype: object

# %%
income_df = pd.read_csv('../data/irs_county_2016.csv')

# %%
income_df.head(2)
# Out:
#    STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1  MARS2  \
# 0          1    AL           0    Alabama         1   26450   14680   9740
# 1          1    AL           0    Alabama         2  285760  217880  25170
#
#    MARS4    PREP  ...  N10300  A10300  N85530  A85530  N85300  A85300  N11901  \
# 0    680   17780  ...    4300    9256      70      57       0       0    2590
# 1  39740  143390  ...   70050   40569       0       0       0       0   22720
#
#    A11901  N11902  A11902
# 0    3685   11510   35079
# 1   11109  237630  263152
#
# [2 rows x 148 columns]

# %%
TN_income_df = income_df.loc[income_df['STATE'] == 'TN']

# %%
TN_income_df.head()
# Out:
#        STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1  \
# 19752         47    TN           0  Tennessee         1   39580   22400
# 19753         47    TN           0  Tennessee         2  439770  345410
# 19754         47    TN           0  Tennessee         3  717430  398720
# 19755         47    TN           0  Tennessee         4  759340  355970
# 19756         47    TN           0  Tennessee         5  396810  128390
#
#         MARS2   MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  \
# 19752   14440     980   25390  ...    6760    17669     200     287       0
# 19753   39920   49300  188490  ...  109250    62045       0       0       0
# 19754  115040  189290  341750  ...  449870   461060       0       0       0
# 19755  217710  159890  347430  ...  629080  1669328     110     100       0
# 19756  215890   42240  198820  ...  382580  2135577      30      29       0
#
#        A85300  N11901  A11901  N11902   A11902
# ...

# %%
TN_income_df.tail()
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub     N1  mars1  \
# 20515         47    TN         189  Wilson County         4  14400   7130
# 20516         47    TN         189  Wilson County         5   9330   2890
# 20517         47    TN         189  Wilson County         6   7160   1060
# 20518         47    TN         189  Wilson County         7  10350    780
# 20519         47    TN         189  Wilson County         8   2370    180
#
#        MARS2  MARS4  PREP  ...  N10300  A10300  N85530  A85530  N85300  \
# 20515   4050   2610  6520  ...   12340   34654       0       0       0
# 20516   5160    960  4600  ...    9010   50591       0       0       0
# 20517   5630    380  3560  ...    7110   61964       0       0       0
# 20518   9260    240  5330  ...   10330  190229      60      13       0
# 20519   2130     50  1700  ...    2370  230759    1160    1817    1080
#
#        A85300  N11901  A11901  N11902  A11902
# 20515       0    2090    4150   12140   31712
# ...

# %%
TN_income_df.
# Out:
# (768, 148)

# %%
TN_income_df.shape

# %%
TN_income_df_editedcolumns = TN_income_df[['STATE','COUNTYNAME','agi_stub','N1','mars1','MARS2','MARS4','N2','NUMDEP','ELDERLY','A00100','N02650', 'A02650','N02300','A02300']]

# %%
TN_income_df.loc[ : , ['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1', 'MARS2', 'MARS4', 'N2', 'NUMDEP', 'ELDERLY', 'A00100', 'N02650', 'A02650', 'N02300', 'A02300']]
TN_income_df = income_df.loc[income_df['STATE'] == 'TN']

# %%
# the result of the following command is the same as the above command.

# %%
income_tn_deletedcolumns = income_tn[['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1',
'MARS2', 'MARS4', 'N2', 'NUMDEP', 'ELDERLY', 'A00100', 'N02650', 'A02650',
'N02300', 'A02300']]

# %%
TN_income_df_editedcolumns.columns = ['state', 'county', 'income_bucket', 'return_count', 'single_returns', 'joint_returns', 'head_of_house_returns', 'exemptions', 'dependents', 'elderly', 'agi', 'returns_with_total_inc','total_inc_amt', 'returns_with_unemployment', 'unemployment_comp']

# %%
TN_income_df_editedcolumns.head(5)
# Out:
#       state     county  income_bucket  return_count  single_returns  \
# 19752    TN  Tennessee              1         39580           22400
# 19753    TN  Tennessee              2        439770          345410
# 19754    TN  Tennessee              3        717430          398720
# 19755    TN  Tennessee              4        759340          355970
# 19756    TN  Tennessee              5        396810          128390
#
#        joint_returns  head_of_house_returns  exemptions  dependents  elderly  \
# 19752          14440                    980       60360        8230    19090
# 19753          39920                  49300      443540      108380    74190
# 19754         115040                 189290     1269420      472350   141070
# 19755         217710                 159890     1486710      512170   154020
# 19756         215890                  42240      881020      268500   106740
#
#             agi  returns_with_total_inc  total_inc_amt  \
# ...
